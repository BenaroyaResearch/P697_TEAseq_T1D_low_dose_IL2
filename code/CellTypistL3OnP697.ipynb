# %%
import scanpy as sc
import celltypist
from celltypist import models
import anndata
import numpy as np

# %%
#Check models path
models.models_path
# Out:
# '/Users/tedwards/.celltypist/data/models'

# %%
model = models.Model.load(model = '84792154-cdfb-42d0-8e42-39e210e980b4_filesets_c5300f8b-f5ff-4010-9371-edc33d489143_ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl')

# %%
counts_file_path = '/Users/tedwards/Documents/projects/P697_TEAseq_T1D_low_dose_IL2/data/outputData/seuratP697AllCells.h5ad'

# %%
adata = anndata.read_h5ad(counts_file_path)
adata.shape
# Out:
# (68131, 2000)

# %%
# to address error: "ValueError: `X_pca` does not have enough PCs. Rerun `sc.pp.pca` with adjusted `n_comps`."
sc.pp.pca(adata, n_comps=50)

# %%
predictions = celltypist.annotate(adata, model = '84792154-cdfb-42d0-8e42-39e210e980b4_filesets_c5300f8b-f5ff-4010-9371-edc33d489143_ref_pbmc_clean_celltypist_model_AIFI_L3_2024-04-19.pkl', majority_voting = True)
# Out:
# 👀 Invalid expression matrix in `.X`, expect log1p normalized expression to 10000 counts per cell; will use `.raw.X` instead
# 🔬 Input data has 68131 cells and 27715 genes
# 🔗 Matching reference genes in the model
# 🧬 2321 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, will construct one before the over-clustering
# ⛓️ Over-clustering input data with resolution set to 20
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
predictions.predicted_labels
# Out:
#                                      predicted_labels over_clustering  \
# pool697-1_1_AAACAGCCAGGCCATT-1        Memory CD4 Treg              53
# pool697-1_1_AAACAGCCATAATCAC-1          CM CD4 T cell             200
# pool697-1_1_AAACATGCACCAGGTT-1     CD56bright NK cell              79
# pool697-1_1_AAACATGCACTAAGTT-1  GZMK- CD56dim NK cell               6
# pool697-1_1_AAACATGCAGCACCAT-1        Memory CD4 Treg              46
# ...                                               ...             ...
# pool697-2_4_TTTGTTGGTGCGCGTA-1          CM CD4 T cell             256
# pool697-2_4_TTTGTTGGTGTTTGTC-1  GZMK- CD56dim NK cell             381
# pool697-2_4_TTTGTTGGTTAGGATT-1  GZMK- CD56dim NK cell               6
# pool697-2_4_TTTGTTGGTTATCCGT-1               CD8 MAIT             269
# pool697-2_4_TTTGTTGGTTGCTGGG-1  GZMK- CD56dim NK cell              23
#
#                                       majority_voting
# pool697-1_1_AAACAGCCAGGCCATT-1        Memory CD4 Treg
# pool697-1_1_AAACAGCCATAATCAC-1        Memory CD4 Treg
# pool697-1_1_AAACATGCACCAGGTT-1  GZMK- CD56dim NK cell
# pool697-1_1_AAACATGCACTAAGTT-1  GZMK- CD56dim NK cell
# pool697-1_1_AAACATGCAGCACCAT-1        Memory CD4 Treg
# ...                                               ...
# pool697-2_4_TTTGTTGGTGCGCGTA-1          CM CD4 T cell
# pool697-2_4_TTTGTTGGTGTTTGTC-1  GZMK- CD56dim NK cell
# pool697-2_4_TTTGTTGGTTAGGATT-1  GZMK- CD56dim NK cell
# pool697-2_4_TTTGTTGGTTATCCGT-1  GZMK- CD56dim NK cell
# pool697-2_4_TTTGTTGGTTGCTGGG-1  GZMK- CD56dim NK cell
#
# [68131 rows x 3 columns]

# %%
adataWithPred = predictions.to_adata()

# %%
adataWithPred.obs.to_csv('20260204_P697_celltypist_L3_predictions.csv')
